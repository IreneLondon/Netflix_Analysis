# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
import matplotlib.cm as cm
import matplotlib as mpl
from matplotlib.gridspec import GridSpec

# %%
netflix_df = pd.read_csv('netflix-rotten-tomatoes-metacritic-imdb.csv')
netflix_df.head(5)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %% [markdown]
# ##### This dataset has 15480 rows and 29 columns

# %% [markdown]
# ### EDA

# %% [markdown]
# #### Cleaning Data

# %%
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  13770 non-null  object
#  2   Tags                   15413 non-null  object
#  3   Languages              13545 non-null  object
#  4   Series or Movie        15480 non-null  object
#  5   Hidden Gem Score       13379 non-null  float64
#  6   Country Availability   15461 non-null  object
#  7   Runtime                15479 non-null  object
#  8   Director               10772 non-null  object
#  9   Writer                 11150 non-null  object
#  10  Actors                 13555 non-null  object
#  11  View Rating            8456 non-null   object
#  12  IMDb Score             13381 non-null  float64
#  13  Rotten Tomatoes Score  6382 non-null   float64
# ...

# %%
netflix_df.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
# removing columns not needed for this analysis
net_df = netflix_df.drop(columns = ['Summary','Image','Writer','Director','TMDb Trailer','Poster','Trailer Site','Actors','Production House','Netflix Link','IMDb Link'])
net_df.head(5)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
net_df.describe()
# Out:
#        Hidden Gem Score    IMDb Score  Rotten Tomatoes Score  \
# count      13379.000000  13381.000000            6382.000000
# mean           5.937551      6.496054              59.523034
# std            2.250202      1.146910              26.999173
# min            0.600000      1.000000               0.000000
# 25%            3.800000      5.800000              38.000000
# 50%            6.800000      6.600000              64.000000
# 75%            7.900000      7.300000              83.000000
# max            9.800000      9.700000             100.000000
#
#        Metacritic Score  Awards Received  Awards Nominated For    IMDb Votes
# count       4336.000000      6075.000000           7661.000000  1.337900e+04
# mean          56.813653         8.764444             13.983161  4.272841e+04
# std           17.582545        18.311171             29.821052  1.257012e+05
# min            5.000000         1.000000              1.000000  5.000000e+00
# ...

# %%
# finding nan values
net_df[net_df.isna().any(axis = 1)]
# Out:
#                                            Title  \
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# 5                               The Con-Heartist
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                    Genre  \
# 1                                 Comedy
# 2                        Drama, Thriller
# 3                                  Drama
# 4                Animation, Short, Drama
# 5                        Comedy, Romance
# ...                                  ...
# 15475                                NaN
# ...

# %%
# replacing nan values with 0
net_df = net_df.replace(np.nan,0)
net_df
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %% [markdown]
# ### Adding new columns

# %%
# Converting Release date into month and year columns
net_df['Release_Month'] = pd.DatetimeIndex(net_df['Release Date']).month
net_df['Release_Year'] = pd.DatetimeIndex(net_df['Release Date']).year

# %%
# Converting Release date into month and year columns
net_df['Netflix_Release_Month'] = pd.DatetimeIndex(net_df['Netflix Release Date']).month
net_df['Netflix_Release_Year'] = pd.DatetimeIndex(net_df['Netflix Release Date']).year

# %%
# Confirming new columns added
net_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  15480 non-null  object
#  2   Tags                   15480 non-null  object
#  3   Languages              15480 non-null  object
#  4   Series or Movie        15480 non-null  object
#  5   Hidden Gem Score       15480 non-null  float64
#  6   Country Availability   15480 non-null  object
#  7   Runtime                15480 non-null  object
#  8   View Rating            15480 non-null  object
#  9   IMDb Score             15480 non-null  float64
#  10  Rotten Tomatoes Score  15480 non-null  float64
#  11  Metacritic Score       15480 non-null  float64
#  12  Awards Received        15480 non-null  float64
#  13  Awards Nominated For   15480 non-null  float64
# ...

# %% [markdown]
# #### UNIVARIATE ANALYSIS

# %%
net_df.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'View Rating',
#        'IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score',
#        'Awards Received', 'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'IMDb Votes', 'Release_Month', 'Release_Year',
#        'Netflix_Release_Month', 'Netflix_Release_Year'],
#       dtype='object')

# %%
net_df['Title'].value_counts()
# Out:
# Godzilla                                    4
# Kingdom                                     4
# Unstoppable                                 3
# Alone                                       3
# Shameless                                   3
#                                            ..
# Whitney Cummings: Can I Touch It?           1
# Twelve Forever                              1
# Tomorrow When the War Began                 1
# Papillon                                    1
# DreamWorks Kung Fu Panda Awesome Secrets    1
# Name: Title, Length: 15071, dtype: int64

# %%
net_df['Genre'].value_counts()
# Out:
# 0                                                   1710
# Comedy                                              1186
# Drama                                               1013
# Documentary                                          460
# Comedy, Drama                                        447
#                                                     ...
# Action, History                                        1
# Action, Adventure, Crime, Drama, Fantasy, Sci-Fi       1
# Animation, Horror, Mystery                             1
# Action, Horror, Romance, War                           1
# Adventure, Drama, Fantasy, Romance, Thriller           1
# Name: Genre, Length: 1781, dtype: int64

# %%
net_df['Tags'].value_counts()
# Out:
# Dramas                                                                                                               68
# 0                                                                                                                    67
# Comedies                                                                                                             37
# Comedies,Russian Movies                                                                                              29
# Stand-up Comedy,Comedies                                                                                             26
#                                                                                                                      ..
# Kids Music,Animal Tales,Children & Family Movies,Family Sci-Fi & Fantasy                                              1
# Independent Movies,Social Issue Dramas,Brazilian Dramas,Dramas,Brazilian Movies                                       1
# ...

# %%
net_df['Languages'].value_counts()
# Out:
# English                        5133
# 0                              1935
# Japanese                       1213
# Korean                          541
# Spanish                         382
#                                ...
# Hungarian, French, English        1
# Arabic, Nyanja, English           1
# Dutch, Flemish                    1
# Thai, Japanese                    1
# English, Hawaiian, Mandarin       1
# Name: Languages, Length: 1439, dtype: int64

# %% [markdown]
# #### Most netflix contents are in English

# %%
net_df['Series or Movie'].value_counts()
# Out:
# Movie     11697
# Series     3783
# Name: Series or Movie, dtype: int64

# %%
plt.hist(net_df['Series or Movie'], bins = 20)
plt.show()

# %% [markdown]
# #### Netflix has more movie contents available than series contents

# %%
net_df['Hidden Gem Score'].value_counts()
# Out:
# 0.0    2101
# 8.0     426
# 7.9     424
# 8.1     417
# 8.2     412
#        ...
# 0.9       3
# 9.7       2
# 0.6       2
# 9.8       1
# 0.7       1
# Name: Hidden Gem Score, Length: 94, dtype: int64

# %%
net_df['Country Availability'].value_counts()
# Out:
# Japan                                                                                                                                                                                                                                                                                                                                1339
# South Korea                                                                                                                                                                                                                                                                                                                           715
# United Kingdom                                                                                                                                                                                                                                                                                                                        340
# ...

# %%
net_df['View Rating'].value_counts()
# Out:
# 0            7024
# R            2096
# PG-13        1373
# Not Rated    1320
# TV-MA        1136
# TV-14         798
# PG            657
# TV-PG         331
# TV-Y          146
# TV-Y7         130
# G             126
# TV-G          125
# Unrated       117
# TV-Y7-FV       33
# Approved       22
# Passed         17
# NC-17           9
# GP              4
# X               4
# E10+            2
# NOT RATED       2
# TV-13           1
# AL              1
# UNRATED         1
# M               1
# U               1
# M/PG            1
# MA-17           1
# E               1
# Name: View Rating, dtype: int64

# %%
net_df['IMDb Score'].value_counts()
# Out:
# 0.0    2099
# 6.5     508
# 6.6     507
# 6.8     504
# 6.3     498
#        ...
# 1.6       2
# 9.4       1
# 9.7       1
# 1.5       1
# 1.0       1
# Name: IMDb Score, Length: 84, dtype: int64

# %%
net_df['Rotten Tomatoes Score'].value_counts()
# Out:
# 0.0      9174
# 100.0     193
# 80.0      138
# 67.0      133
# 50.0      119
#          ...
# 6.0        12
# 5.0        10
# 3.0         8
# 1.0         4
# 2.0         2
# Name: Rotten Tomatoes Score, Length: 101, dtype: int64

# %%
net_df['Runtime'].value_counts()
# Out:
# 1-2 hour        9121
# < 30 minutes    3996
# > 2 hrs         2028
# 30-60 mins       334
# 0                  1
# Name: Runtime, dtype: int64

# %% [markdown]
# #### Most contents on netflix run between 1-2 hours

# %%
net_df['Metacritic Score'].value_counts()
# Out:
# 0.0     11144
# 51.0      109
# 66.0      104
# 68.0       99
# 63.0       97
#         ...
# 9.0         2
# 8.0         1
# 10.0        1
# 5.0         1
# 6.0         1
# Name: Metacritic Score, Length: 96, dtype: int64

# %%
net_df['Awards Received'].value_counts()
# Out:
# 0.0      9405
# 1.0      1692
# 2.0       964
# 3.0       584
# 4.0       463
#          ...
# 300.0       1
# 194.0       1
# 104.0       1
# 239.0       1
# 152.0       1
# Name: Awards Received, Length: 131, dtype: int64

# %%
net_df['Awards Nominated For'].value_counts()
# Out:
# 0.0      7819
# 1.0      1525
# 2.0       942
# 3.0       680
# 4.0       518
#          ...
# 248.0       1
# 165.0       1
# 112.0       1
# 263.0       1
# 138.0       1
# Name: Awards Nominated For, Length: 201, dtype: int64

# %%
net_df['Boxoffice'].value_counts()
# Out:
# 0               11473
# $474,544,677       12
# $509                9
# $2,223,961          8
# $27,007,844         6
#                 ...
# $3,029,287          1
# $54,461,047         1
# $3,814,868          1
# $30,971,040         1
# $57,231,747         1
# Name: Boxoffice, Length: 3837, dtype: int64

# %%
net_df['Release Date'].value_counts()
# Out:
# 0              2107
# 21 Sep 2018      24
# 12 Oct 2018      24
# 01 Sep 2017      24
# 12 Apr 2019      23
#                ...
# 28 May 1993       1
# 24 Aug 2011       1
# 16 Aug 2003       1
# 29 May 2011       1
# 17 Sep 1988       1
# Name: Release Date, Length: 5315, dtype: int64

# %%
net_df['Runtime'].value_counts()
# Out:
# 1-2 hour        9121
# < 30 minutes    3996
# > 2 hrs         2028
# 30-60 mins       334
# 0                  1
# Name: Runtime, dtype: int64

# %%
net_df['Netflix Release Date'].value_counts()
# Out:
# 2015-04-14    2407
# 2020-12-12     159
# 2015-09-01     154
# 2018-10-01     136
# 2020-11-27     114
#               ...
# 2017-06-14       1
# 2017-06-21       1
# 2017-06-24       1
# 2017-06-25       1
# 2015-11-12       1
# Name: Netflix Release Date, Length: 1823, dtype: int64

# %%
net_df['Release_Month'].value_counts()
# Out:
# 1     3236
# 10    1400
# 9     1266
# 11    1192
# 12    1150
# 3     1112
# 4     1109
# 8     1104
# 7     1031
# 2      995
# 6      964
# 5      921
# Name: Release_Month, dtype: int64

# %%
plt.hist(net_df['Release_Month'],bins = 30)
plt.show()

# %% [markdown]
# #### Most contents were orignally released in January.

# %%
net_df['Release_Year'].value_counts()
# Out:
# 1970    2116
# 2018    1495
# 2017    1408
# 2019    1330
# 2016    1097
#         ...
# 1946       1
# 2022       1
# 1914       1
# 1943       1
# 1936       1
# Name: Release_Year, Length: 105, dtype: int64

# %%
plt.hist(net_df['Release_Year'],bins = 10)
plt.show()

# %% [markdown]
# #### Most contents on netflix were originally released between 2010 and 2020. Also the data tells how less original netflix contents are available.

# %%
net_df['Netflix_Release_Month'].value_counts()
# Out:
# 4     3462
# 12    1810
# 11    1358
# 9     1225
# 10    1195
# 1      987
# 7      968
# 2      913
# 3      910
# 6      903
# 8      902
# 5      847
# Name: Netflix_Release_Month, dtype: int64

# %%
plt.hist(net_df['Netflix_Release_Month'],bins = 30)
plt.show()

# %% [markdown]
# #### Netflix released 3462 contents in the month of April which was the month of Covid lockdown was mandatory for all persons.
# #### Hence Netflix released more content to fill the thirst of entertainment by Individuals accross the world.
# #### April recorded the highest released month as a result of the high release of content in 2020 also.

# %%
net_df['Netflix_Release_Year'].value_counts()
# Out:
# 2020    3698
# 2015    3260
# 2019    2722
# 2018    2128
# 2017    1643
# 2016    1344
# 2021     685
# Name: Netflix_Release_Year, dtype: int64

# %%
plt.hist(net_df['Netflix_Release_Year'],bins = 20)
plt.show()

# %% [markdown]
# #### Netflix released 3698 content in 2020. This might be as a result of the covid 19 world wide pandemic.
# #### This Pandemic rendered the world to come to a stand still as a result of a mandatory lockdown.

# %% [markdown]
# ### Comparing the Runtime to the various scores,Vote and Dates
#
# ### Aggregation - Runtime

# %%
net_df.groupby('Runtime').sum()
# Out:
#               Hidden Gem Score  IMDb Score  Rotten Tomatoes Score  \
# Runtime
# 0                          7.8         7.8                    0.0
# 1-2 hour               44791.6     49301.5               273288.0
# 30-60 mins              1823.3      1536.7                 2868.0
# < 30 minutes           22694.9     23047.0                13527.0
# > 2 hrs                10120.9     13030.7                90193.0
#
#               Metacritic Score  Awards Received  Awards Nominated For  \
# Runtime
# 0                          0.0              2.0                   3.0
# 1-2 hour              181946.0          25022.0               48852.0
# 30-60 mins                53.0             78.0                 134.0
# < 30 minutes            6690.0           8879.0               21750.0
# > 2 hrs                57655.0          19263.0               36386.0
#
#                IMDb Votes  Release_Month  Release_Year  Netflix_Release_Month  \
# Runtime
# ...

# %% [markdown]
# #### SCORES

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Hidden Gem Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Hidden Gem Score'>

# %% [markdown]
# #### Highest score for Hidden Gem Score contents are ones between 1-2 hours and the least being ones with 0 and 30-60min.
# #### TOP 3 Highest Score
# #### 1-2hrs
# #### < 30min
# #### >2 hrs

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['IMDb Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='IMDb Score'>

# %% [markdown]
# #### Highest score for IMDb Score contents are ones between 1-2 hours and the least being ones with 0 and 30-60min.
# #### TOP 3 Highest Score
# #### 1-2hrs
# #### <30min
# #### >2 hrs

# %%
plt.figure(figsize = (10,10))
net_df.groupby('Runtime').sum()['Rotten Tomatoes Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Rotten Tomatoes Score'>

# %% [markdown]
# #### Highest score for Rotten Tomatoes Score contents are ones between 1-2 hours and the least being ones with 0 and 30-60min.
# #### TOP 3 Highest Score
# #### 1-2hrs
# #### >2hrs
# #### <30 minutes

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Metacritic Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Metacritic Score'>

# %% [markdown]
# #### Highest score from Metacritic Score have contents with runtime 1-2 hours and the least is 0 and 30-60min.
# #### TOP 3 Highest scored
# #### 1-2hrs
# #### >2hrs
# #### < 30 minutes

# %% [markdown]
# #### Here the 4 graphs above show that, the least scored contents by critics on netflix are the ones with runtime 30-60min.
# #### And the most critiqued have runtime 1-2hrs.

# %% [markdown]
# ### Awards Received And Nominated For

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Awards Received'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Awards Received'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Awards Nominated For'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Awards Nominated For'>

# %% [markdown]
# ### Votes

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['IMDb Votes'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='IMDb Votes'>

# %% [markdown]
# #### Highest vote from IMDb votes were contents with 1-2 hours runtime and the least being ones with 0 and 30-60min.
# #### TOP 3 Highest Voted
# #### 1-2hrs
# #### >2 hrs
# #### <30minutes

# %% [markdown]
# ### Released Month and Year

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Release_Month'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Release_Month'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Release_Year'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Release_Year'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Netflix_Release_Year'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Netflix_Release_Year'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Runtime').sum()['Netflix_Release_Month'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Netflix_Release_Month'>

# %% [markdown]
# ### Aggregation - Series Or Movie

# %%
net_df.groupby('Series or Movie').sum()
# Out:
#                  Hidden Gem Score  IMDb Score  Rotten Tomatoes Score  \
# Series or Movie
# Movie                     57753.5     64842.6               368572.0
# Series                    21685.0     22081.1                11304.0
#
#                  Metacritic Score  Awards Received  Awards Nominated For  \
# Series or Movie
# Movie                    241203.0          44689.0               85759.0
# Series                     5141.0           8555.0               21366.0
#
#                   IMDb Votes  Release_Month  Release_Year  \
# Series or Movie
# Movie            515844712.0          71245      23460767
# Series            55818707.0          20497       7584307
#
#                  Netflix_Release_Month  Netflix_Release_Year
# Series or Movie
# Movie                            77152              23602529
# Series                           25517               7634173

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').count()['Languages'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Languages'>

# %% [markdown]
# #### Movie contents are in more languages than series contents

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Hidden Gem Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Hidden Gem Score'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['IMDb Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='IMDb Score'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Rotten Tomatoes Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Rotten Tomatoes Score'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Metacritic Score'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Metacritic Score'>

# %% [markdown]
# #### More movie contents are critqued and scored more than series contents

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Awards Received'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Awards Received'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Awards Nominated For'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Awards Nominated For'>

# %% [markdown]
# #### Movie contents get nominated and awarded more than series contents.

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['IMDb Votes'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='IMDb Votes'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Release_Month'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Release_Month'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Release_Year'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Release_Year'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Netflix_Release_Month'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Netflix_Release_Month'>

# %%
plt.figure(figsize = (5,5))
net_df.groupby('Series or Movie').sum()['Netflix_Release_Year'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Netflix_Release_Year'>

# %% [markdown]
# #### There are more movie content on Netflix than series content up until 2020

# %% [markdown]
# ### Aggregation - View Rating

# %%
net_df.groupby(['View Rating']).sum()
# Out:
#              Hidden Gem Score  IMDb Score  Rotten Tomatoes Score  \
# View Rating
# 0                     37745.1     31470.6                60360.0
# AL                        8.6         7.4                    0.0
# Approved                146.2       149.1                 1010.0
# E                         8.3         7.3                    0.0
# E10+                     15.8        12.9                    0.0
# G                       691.2       819.6                 6359.0
# GP                       25.3        27.4                  225.0
# M                         7.8         5.8                    0.0
# M/PG                      4.2         7.4                   97.0
# MA-17                     4.2         7.2                   94.0
# NC-17                    35.4        63.6                  661.0
# NOT RATED                 9.0         8.0                    0.0
# Not Rated              7932.9      8517.8                59440.0
# ...

# %% [markdown]
# ### Plotting View Rating with against Awards nominated for and received

# %%
plt.figure(figsize = (10,10))
net_df.groupby(['View Rating']).sum()['Awards Nominated For'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Awards Nominated For'>

# %% [markdown]
# #### R rated shows recieved the most award nominations followed by PG 13 shows coming in as second highest with Passed,AL,M,NOT RATED,TV 13,U, UNRATED  shows having no nominations.

# %%
plt.figure(figsize = (15,10))
net_df.groupby(['View Rating']).sum()['Awards Received'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Awards Received'>

# %% [markdown]
# #### R rated shows received most awards for their nominations.They recieved 34.7% awards out of the 35.0% they were nominated for. However, Passed shows received no nominations but has 0.1% for awards received.

# %% [markdown]
# ### Plotting View Rating against Release Year and Month

# %% [markdown]
# ### MONTH

# %%
plt.figure(figsize = (10,10))
net_df.groupby('View Rating').count()['Languages'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Languages'>

# %%
plt.figure(figsize = (15,10))
net_df.groupby(['View Rating']).sum()['Release_Month'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Release_Month'>

# %%
plt.figure(figsize = (15,10))
net_df.groupby(['View Rating']).sum()['Netflix_Release_Month'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Netflix_Release_Month'>

# %% [markdown]
# ### YEAR

# %%
plt.figure(figsize = (15,10))
net_df.groupby(['View Rating']).sum()['Release_Year'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Release_Year'>

# %%
plt.figure(figsize = (15,10))
net_df.groupby(['View Rating']).sum()['Netflix_Release_Year'].plot(kind = 'pie',autopct = '%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Netflix_Release_Year'>

# %% [markdown]
# #### From here we notice the is an increase in the 0 segment of the Netflix Release year graph as oppose to the percentage of the Released Years with figures 45.4% and 45.3% respectively. Netflix released content on Netflix release year than the actual Release year, this is because contents on netflix are either original netflix contents or they are purchase from other production/streaming houses.So the Netflix_Release_Year having a 1% content increase of the 0 segment means there were releases of original netflix content rated 0.
# #### And also most of the contents where released after they were origianally released.
#
# #### However,The view rating segments R and TV MA has the opposite happening. They record a 1% decrease in contents released on Netflix Release Year than Release Year. R and TV MA recorded 13.6% and 7.4% respectively for Release Year and 13.5% and 7.3% for Netflix Released Dates.These might be because netflix released less R and TV Ma rated content after their orignal releases.
